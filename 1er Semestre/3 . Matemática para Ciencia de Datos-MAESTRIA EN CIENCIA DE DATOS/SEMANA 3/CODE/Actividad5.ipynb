# %%
import lifelines
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data_prev = pd.read_csv('Data/Employee_Attrition.csv')

# %%
data_prev.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ## 1. Data Exploration

# %%
data_prev.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data_prev.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
data = data_prev.select_dtypes(include = 'int64')

# %%
data.dtypes
# Out:
# Age                         int64
# DailyRate                   int64
# DistanceFromHome            int64
# Education                   int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %%
data['Attrition'] = data_prev['Attrition']

# %%
data.dtypes
# Out:
# Age                          int64
# DailyRate                    int64
# DistanceFromHome             int64
# Education                    int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobSatisfaction              int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# Attrition                   object
# dtype: object

# %%
data['Attrition'] = data['Attrition'].map({'Yes': 1, 'No': 0})

# %%
data.head(90)
# Out:
#     Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0    41       1102                 1          2              1
# 1    49        279                 8          1              1
# 2    37       1373                 2          2              1
# 3    33       1392                 3          4              1
# 4    27        591                 2          1              1
# ..  ...        ...               ...        ...            ...
# 85   56       1400                 7          3              1
# 86   23        541                 2          1              1
# 87   51        432                 9          4              1
# 88   30        288                 2          3              1
# 89   46        669                 9          2              1
#
#     EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                1                        2          94               3
# 1                2                        3          61               2
# 2                4                        4          92               2
# 3                5                        4          56               3
# 4                7                        1          40               3
# ..             ...                      ...         ...             ...
# 85             112                        4          49               1
# 86             113                        3          62               3
# 87             116                        4          96               3
# 88             117                        3          99               2
# 89             118                        3          64               2
#
#     JobLevel  ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0          2  ...             80                 0                  8
# 1          2  ...             80                 1                 10
# 2          1  ...             80                 0                  7
# 3          1  ...             80                 0                  8
# 4          1  ...             80                 1                  6
# ..       ...  ...            ...               ...                ...
# 85         3  ...             80                 0                 37
# 86         1  ...             80                 1                  3
# 87         1  ...             80                 2                 10
# 88         2  ...             80                 3                 11
# 89         3  ...             80                 0                  9
#
#     TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                       0                1               6
# 1                       3                3              10
# 2                       3                3               0
# 3                       3                3               8
# 4                       3                3               2
# ..                    ...              ...             ...
# 85                      3                2               6
# 86                      3                3               0
# 87                      4                3               4
# 88                      3                3              11
# 89                      3                3               9
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                    4                        0                     5
# 1                    7                        1                     7
# 2                    0                        0                     0
# 3                    7                        3                     0
# 4                    2                        2                     2
# ..                 ...                      ...                   ...
# 85                   4                        0                     2
# 86                   0                        0                     0
# 87                   2                        0                     3
# 88                  10                       10                     8
# 89                   8                        4                     7
#
#     Attrition
# 0           1
# 1           0
# 2           1
# 3           0
# 4           0
# ..        ...
# 85          0
# 86          0
# 87          0
# 88          0
# 89          1
#
# [90 rows x 27 columns]

# %%
data.isnull().sum()
# Out:
# Age                         0
# DailyRate                   0
# DistanceFromHome            0
# Education                   0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobSatisfaction             0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# Attrition                   0
# dtype: int64

# %%
data = data.drop('EmployeeCount', 'StandardHours', axis = 1)

# %%
data=data[['DailyRate', 'DistanceFromHome', 'Education',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age', 'Attrition' ]]   # Ordenar el data set data=[X,T,E]  = EN Ml clasico X=X+T

# %%
df_corr = data.corr(method='spearman')
fig, ax = plt.subplots(figsize=(15,15))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# plot heatmap
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='BrBG',
           vmin=-1, vmax=1, cbar_kws={"shrink": 1})
#    sns.set(font_scale=1)
# yticks
plt.yticks(rotation=0)
plt.show()

# %%
pd.crosstab(data.Age,data.Attrition,margins=True)
# Out:
# Attrition     0    1   All
# Age
# 18            4    4     8
# 19            3    6     9
# 20            5    6    11
# 21            7    6    13
# 22           11    5    16
# 23           10    4    14
# 24           19    7    26
# 25           20    6    26
# 26           27   12    39
# 27           45    3    48
# 28           34   14    48
# 29           50   18    68
# 30           51    9    60
# 31           51   18    69
# 32           50   11    61
# 33           46   12    58
# 34           68    9    77
# 35           68   10    78
# 36           63    6    69
# 37           44    6    50
# 38           56    2    58
# 39           36    6    42
# 40           52    5    57
# 41           34    6    40
# 42           44    2    46
# 43           30    2    32
# 44           27    6    33
# 45           39    2    41
# 46           29    4    33
# 47           21    3    24
# 48           17    2    19
# 49           22    2    24
# 50           25    5    30
# 51           17    2    19
# 52           15    3    18
# 53           17    2    19
# 54           18    0    18
# 55           19    3    22
# 56           11    3    14
# 57            4    0     4
# 58            9    5    14
# 59           10    0    10
# 60            5    0     5
# All        1233  237  1470

# %%
100*pd.crosstab(data.Age,data.Attrition,normalize='index').round(4)
# Out:
# Attrition       0      1
# Age
# 18          50.00  50.00
# 19          33.33  66.67
# 20          45.45  54.55
# 21          53.85  46.15
# 22          68.75  31.25
# 23          71.43  28.57
# 24          73.08  26.92
# 25          76.92  23.08
# 26          69.23  30.77
# 27          93.75   6.25
# 28          70.83  29.17
# 29          73.53  26.47
# 30          85.00  15.00
# 31          73.91  26.09
# 32          81.97  18.03
# 33          79.31  20.69
# 34          88.31  11.69
# 35          87.18  12.82
# 36          91.30   8.70
# 37          88.00  12.00
# 38          96.55   3.45
# 39          85.71  14.29
# 40          91.23   8.77
# 41          85.00  15.00
# 42          95.65   4.35
# 43          93.75   6.25
# 44          81.82  18.18
# 45          95.12   4.88
# 46          87.88  12.12
# 47          87.50  12.50
# 48          89.47  10.53
# 49          91.67   8.33
# 50          83.33  16.67
# 51          89.47  10.53
# 52          83.33  16.67
# 53          89.47  10.53
# 54         100.00   0.00
# 55          86.36  13.64
# 56          78.57  21.43
# 57         100.00   0.00
# 58          64.29  35.71
# 59         100.00   0.00
# 60         100.00   0.00

# %%
data['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
data.describe()
# Out:
#          DailyRate  DistanceFromHome    Education  EmployeeNumber  \
# count  1470.000000       1470.000000  1470.000000     1470.000000
# mean    802.485714          9.192517     2.912925     1024.865306
# std     403.509100          8.106864     1.024165      602.024335
# min     102.000000          1.000000     1.000000        1.000000
# 25%     465.000000          2.000000     2.000000      491.250000
# 50%     802.000000          7.000000     3.000000     1020.500000
# 75%    1157.000000         14.000000     4.000000     1555.750000
# max    1499.000000         29.000000     5.000000     2068.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    48.000000        2.000000     1.000000
# 50%                   3.000000    66.000000        3.000000     2.000000
# 75%                   4.000000    83.750000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome  ...  StockOptionLevel  \
# count      1470.000000    1470.000000  ...       1470.000000
# mean          2.728571    6502.931293  ...          0.793878
# std           1.102846    4707.956783  ...          0.852077
# min           1.000000    1009.000000  ...          0.000000
# 25%           2.000000    2911.000000  ...          0.000000
# 50%           3.000000    4919.000000  ...          1.000000
# 75%           4.000000    8379.000000  ...          1.000000
# max           4.000000   19999.000000  ...          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1470.000000            1470.000000      1470.000000
# mean           11.279592               2.799320         2.761224
# std             7.780782               1.289271         0.706476
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%            10.000000               3.000000         3.000000
# 75%            15.000000               3.000000         3.000000
# max            40.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1470.000000         1470.000000              1470.000000
# mean         7.008163            4.229252                 2.187755
# std          6.126525            3.623137                 3.222430
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 3.000000
# max         40.000000           18.000000                15.000000
#
#        YearsWithCurrManager          Age    Attrition
# count           1470.000000  1470.000000  1470.000000
# mean               4.123129    36.923810     0.161224
# std                3.568136     9.135373     0.367863
# min                0.000000    18.000000     0.000000
# 25%                2.000000    30.000000     0.000000
# 50%                3.000000    36.000000     0.000000
# 75%                7.000000    43.000000     0.000000
# max               17.000000    60.000000     1.000000
#
# [8 rows x 25 columns]

# %%
data[(data.Attrition==1)&(data.Age>=36)]  
data[(data.Attrition==1)&(data.Age<36)]
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 34          813                 1          3              45
# 102         871                 6          3             137
# 127         528                22          1             167
# 171         602                 1          1             235
# 177         303                 2          3             243
# 296         230                 3          3             405
# 357         756                 1          1             478
# 370         156                12          3             494
# 414        1448                 1          1             554
# 422         489                 2          2             566
# 443        1368                 4          1             593
# 457        1306                 5          3             614
# 479        1287                 7          3             647
# 513        1362                10          1             701
# 525         693                 3          2             720
# 585        1243                 6          3             811
# 662         500                 2          3             922
# 663        1427                18          1             923
# 666         617                 3          1             926
# 688         419                21          3             959
# 689         129                 4          3             960
# 731        1097                11          3            1016
# 776         769                 9          3            1077
# 777        1334                10          3            1079
# 828         247                 8          1            1156
# 860        1256                 3          4            1203
# 871         984                17          2            1219
# 892         504                10          3            1248
# 915         251                10          2            1279
# 1060        381                 9          3            1494
# 1153        544                 3          2            1624
# 1201       1320                 8          1            1684
# 1213        427                 7          3            1702
# 1222        240                22          1            1714
# 1271        337                 7          1            1780
# 1273       1294                 8          1            1783
# 1339        391                 7          1            1878
# 1438        638                 9          3            2023
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 34                          2          61               3         1
# 102                         4          66               2         1
# 127                         4          50               3         1
# 171                         3         100               1         1
# 177                         2          47               2         1
# 296                         3          54               3         1
# 357                         1          99               2         1
# 370                         3          90               4         1
# 414                         1          62               3         1
# 422                         1          52               2         1
# 443                         3          99               2         1
# 457                         2          69               3         1
# 479                         1          55               3         1
# 513                         4          32               3         1
# 525                         1          65               3         2
# 585                         3          63               4         1
# 662                         3          49               2         1
# 663                         4          65               3         1
# 666                         2          34               3         2
# 688                         4          37               2         1
# 689                         1          84               3         1
# 731                         4          98               2         1
# 776                         4          54               3         1
# 777                         3          36               2         1
# 828                         3          80               3         1
# 860                         3          48               2         1
# 871                         4          97               3         1
# 892                         1          96               2         1
# 915                         1          45               2         1
# 1060                        2          89               3         1
# 1153                        2          70               3         1
# 1201                        4          93               2         1
# 1213                        3          99               3         1
# 1222                        4          58               1         1
# 1271                        2          31               3         1
# 1273                        3          79               3         1
# 1339                        4          75               3         1
# 1438                        4          33               3         1
#
#       JobSatisfaction  MonthlyIncome  ...  StockOptionLevel  \
# 34                  4           2293  ...                 1
# 102                 4           2926  ...                 0
# 127                 3           1675  ...                 0
# 171                 1           2325  ...                 0
# 177                 4           1102  ...                 0
# 296                 3           1420  ...                 0
# 357                 2           2174  ...                 0
# 370                 2           2716  ...                 0
# 414                 2           3202  ...                 0
# 422                 4           2564  ...                 0
# 443                 3           3894  ...                 0
# 457                 2           1878  ...                 0
# 479                 3           2886  ...                 1
# 513                 3           1009  ...                 0
# 525                 3           4577  ...                 0
# 585                 1           1601  ...                 2
# 662                 3           2044  ...                 0
# 663                 4           2693  ...                 0
# 666                 3           4171  ...                 1
# 688                 2           2121  ...                 0
# 689                 1           2973  ...                 0
# 731                 1           2600  ...                 0
# 776                 4           2323  ...                 0
# 777                 1           1416  ...                 0
# 828                 3           1904  ...                 0
# 860                 4           2853  ...                 1
# 871                 2           2210  ...                 1
# 892                 2           1859  ...                 0
# 915                 3           2625  ...                 0
# 1060                1           3172  ...                 0
# 1153                4           1569  ...                 0
# 1201                3           3989  ...                 0
# 1213                4           2275  ...                 1
# 1222                3           1555  ...                 1
# 1271                2           2679  ...                 0
# 1273                1           2398  ...                 0
# 1339                2           2472  ...                 0
# 1438                1           1790  ...                 1
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 34                    6                      2                2
# 102                   1                      5                3
# 127                   0                      2                2
# 171                   1                      5                4
# 177                   1                      3                2
# 296                   0                      2                3
# 357                   3                      3                3
# 370                   1                      0                3
# 414                   6                      4                3
# 422                   1                      3                4
# 443                   4                      3                3
# 457                   0                      3                3
# 479                   6                      4                3
# 513                   1                      5                3
# 525                   4                      3                3
# 585                   1                      2                3
# 662                   2                      3                2
# 663                   1                      3                2
# 666                   4                      3                4
# 688                   1                      3                4
# 689                   1                      2                3
# 731                   1                      2                3
# 776                   2                      3                3
# 777                   1                      6                2
# 828                   0                      0                3
# 860                   1                      5                3
# 871                   1                      3                1
# 892                   1                      2                4
# 915                   2                      2                1
# 1060                  4                      2                2
# 1153                  0                      2                4
# 1201                  5                      2                3
# 1213                  3                      2                3
# 1222                  1                      2                3
# 1271                  1                      3                3
# 1273                  1                      6                3
# 1339                  1                      2                3
# 1438                  1                      3                2
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 34                 2                   0                        2
# 102                1                   0                        1
# 127                0                   0                        0
# 171                0                   0                        0
# 177                1                   0                        1
# 296                0                   0                        0
# 357                3                   2                        1
# 370                1                   0                        0
# 414                5                   3                        1
# 422                1                   0                        0
# 443                2                   2                        1
# 457                0                   0                        0
# 479                6                   3                        1
# 513                1                   0                        1
# 525                2                   2                        2
# 585                0                   0                        0
# 662                2                   2                        0
# 663                1                   0                        0
# 666                3                   2                        0
# 688                1                   0                        0
# 689                1                   0                        0
# 731                1                   0                        0
# 776                2                   2                        0
# 777                1                   0                        1
# 828                0                   0                        0
# 860                0                   0                        0
# 871                1                   0                        0
# 892                1                   1                        0
# 915                2                   2                        2
# 1060               0                   0                        0
# 1153               0                   0                        0
# 1201               5                   4                        1
# 1213               3                   2                        0
# 1222               1                   0                        0
# 1271               1                   0                        1
# 1273               1                   0                        0
# 1339               1                   0                        0
# 1438               1                   0                        1
#
#       YearsWithCurrManager  Age  Attrition
# 34                       0   24          1
# 102                      0   20          1
# 127                      0   19          1
# 171                      0   19          1
# 177                      0   19          1
# 296                      0   18          1
# 357                      2   21          1
# 370                      0   21          1
# 414                      4   24          1
# 422                      0   19          1
# 443                      2   22          1
# 457                      0   18          1
# 479                      2   24          1
# 513                      1   20          1
# 525                      0   24          1
# 585                      0   23          1
# 662                      2   20          1
# 663                      0   21          1
# 666                      2   22          1
# 688                      0   19          1
# 689                      0   20          1
# 731                      0   20          1
# 776                      2   20          1
# 777                      0   21          1
# 828                      0   18          1
# 860                      0   22          1
# 871                      0   24          1
# 892                      0   19          1
# 915                      2   21          1
# 1060                     0   24          1
# 1153                     0   18          1
# 1201                     2   23          1
# 1213                     2   23          1
# 1222                     0   24          1
# 1271                     0   21          1
# 1273                     0   22          1
# 1339                     0   22          1
# 1438                     0   23          1
#
# [38 rows x 25 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Comparison of EmployeeNumber according to Age >= 36 or < 36')
ax1.boxplot(data[(data.Attrition==1)&(data.Age>=36)].EmployeeNumber,showfliers=False,showmeans=True)
ax2.boxplot(data[(data.Attrition==1)&(data.Age<36)].EmployeeNumber,showfliers=False,showmeans=True)
plt.show()

# %%
dd=data[(data.Attrition==1)&(data.Age>=36)]
dd0=data[(data.Attrition==1)&(data.Age<36)]

# %%
print(dd.EmployeeNumber.mean())
print(dd0.EmployeeNumber.mean())
# Out:
# 990.9350649350649
# 1019.6875

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Comparison of EmployeeNumber according to age > 36 or < 36')
ax1.hist(data[(data.Attrition==1)&(data.Age>=36)].EmployeeNumber,bins=5)
ax2.hist(data[(data.Attrition==1)&(data.Age<36)].EmployeeNumber,bins=5)
plt.show()

# %%
data_sample=data.sample(6,random_state=123)

# %%
data_sample
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 42         1357                25          3              55
# 76          776                 1          4             100
# 1380        682                18          4            1945
# 252         665                15          3             346
# 388         201                 1          4             517
# 1206        786                 7          3            1693
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 42                          1          48               1         1
# 76                          3          32               2         2
# 1380                        2          71               3         2
# 252                         3          60               3         1
# 388                         2          95               3         1
# 1206                        4          76               3         1
#
#       JobSatisfaction  MonthlyIncome  ...  StockOptionLevel  \
# 42                  3           2293  ...                 0
# 76                  1           4312  ...                 0
# 1380                1           5561  ...                 1
# 252                 4           2340  ...                 0
# 388                 1           2576  ...                 1
# 1206                4           2570  ...                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 42                    1                      2                2
# 76                   16                      2                3
# 1380                  6                      2                1
# 252                   6                      1                3
# 388                   8                      5                3
# 1206                  7                      5                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 42                 1                   0                        0
# 76                15                  13                        2
# 1380               5                   3                        0
# 252                6                   5                        1
# 388                5                   2                        1
# 1206               7                   7                        5
#
#       YearsWithCurrManager  Age  Attrition
# 42                       1   26          1
# 76                       8   35          0
# 1380                     4   35          0
# 252                      5   29          0
# 388                      2   42          0
# 1206                     7   26          0
#
# [6 rows x 25 columns]

# %%
plt.figure(figsize=(10,4))
time = data_sample.Age
event = data_sample.Attrition
lifelines.plotting.plot_lifetimes(durations=time, event_observed=event)
plt.plot()
# Out:
# []

# %%
df_corr = data.corr(method='spearman')
fig, ax = plt.subplots(figsize=(15,15))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# plot heatmap
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='BrBG',
           vmin=-1, vmax=1, cbar_kws={"shrink": 1})
#    sns.set(font_scale=1)
# yticks
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ## 2. Kaplan-Meier estimator

# %%
kmf = lifelines.KaplanMeierFitter()

T = data.Age
E = data.Attrition
kmf.fit(T, E)
kmf.survival_function_.plot()
plt.title('Survival Curve')
#plt.ylim(0,1);
# Out:
# Text(0.5, 1.0, 'Survival Curve')

# %%
kmf.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %%
kmf.event_table
# Out:
#           removed  observed  censored  entrance  at_risk
# event_at
# 0.0             0         0         0      1470     1470
# 18.0            8         4         4         0     1470
# 19.0            9         6         3         0     1462
# 20.0           11         6         5         0     1453
# 21.0           13         6         7         0     1442
# 22.0           16         5        11         0     1429
# 23.0           14         4        10         0     1413
# 24.0           26         7        19         0     1399
# 25.0           26         6        20         0     1373
# 26.0           39        12        27         0     1347
# 27.0           48         3        45         0     1308
# 28.0           48        14        34         0     1260
# 29.0           68        18        50         0     1212
# 30.0           60         9        51         0     1144
# 31.0           69        18        51         0     1084
# 32.0           61        11        50         0     1015
# 33.0           58        12        46         0      954
# 34.0           77         9        68         0      896
# 35.0           78        10        68         0      819
# 36.0           69         6        63         0      741
# 37.0           50         6        44         0      672
# 38.0           58         2        56         0      622
# 39.0           42         6        36         0      564
# 40.0           57         5        52         0      522
# 41.0           40         6        34         0      465
# 42.0           46         2        44         0      425
# 43.0           32         2        30         0      379
# 44.0           33         6        27         0      347
# 45.0           41         2        39         0      314
# 46.0           33         4        29         0      273
# 47.0           24         3        21         0      240
# 48.0           19         2        17         0      216
# 49.0           24         2        22         0      197
# 50.0           30         5        25         0      173
# 51.0           19         2        17         0      143
# 52.0           18         3        15         0      124
# 53.0           19         2        17         0      106
# 54.0           18         0        18         0       87
# 55.0           22         3        19         0       69
# 56.0           14         3        11         0       47
# 57.0            4         0         4         0       33
# 58.0           14         5         9         0       29
# 59.0           10         0        10         0       15
# 60.0            5         0         5         0        5

# %% [markdown]
#  ## 3. Analizar la influencia de una variable .

# %%
# H0: S1(t)=S2(t)
# Ha: S1(t)<>S2(t)

ax = plt.subplot(111)

opc = (data["Age"] >= 36 )
opc1 = (data["Age"] < 36 )


kmf.fit(T[opc], event_observed=E[opc], label="Older than 36 years")
kmf.plot_survival_function(ax=ax)

kmf.fit(T[~opc], event_observed=E[opc1], label="Younger than 36 years")
kmf.plot_survival_function(ax=ax)

plt.title("Survival curves by Age > 36 or < 36");

# %%
from lifelines.statistics import logrank_test

# %%
results = logrank_test(T[opc], T[opc1], E[opc], E[opc1], alpha=.95)

# %%
results
# Out:
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.95
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#          304.54 <0.005    224.13

# %% [markdown]
# ## 4. Cox Proportional Hazards Regression

# %%
data.head()
# Out:
#    DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0       1102                 1          2               1
# 1        279                 8          1               2
# 2       1373                 2          2               4
# 3       1392                 3          4               5
# 4        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  ...  StockOptionLevel  TotalWorkingYears  \
# 0                4           5993  ...                 0                  8
# 1                2           5130  ...                 1                 10
# 2                3           2090  ...                 0                  7
# 3                3           2909  ...                 0                  8
# 4                2           3468  ...                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Age  Attrition
# 0                        0                     5   41          1
# 1                        1                     7   49          0
# 2                        0                     0   37          1
# 3                        3                     0   33          0
# 4                        2                     2   27          0
#
# [5 rows x 25 columns]

# %%
from lifelines import CoxPHFitter

# %%
cph = CoxPHFitter()
cph.fit(data, duration_col='Age', event_col='Attrition')
# Out:
# <lifelines.CoxPHFitter: fitted with 1470 total observations, 1233 right-censored observations>

# %%
data.describe()
# Out:
#          DailyRate  DistanceFromHome    Education  EmployeeNumber  \
# count  1470.000000       1470.000000  1470.000000     1470.000000
# mean    802.485714          9.192517     2.912925     1024.865306
# std     403.509100          8.106864     1.024165      602.024335
# min     102.000000          1.000000     1.000000        1.000000
# 25%     465.000000          2.000000     2.000000      491.250000
# 50%     802.000000          7.000000     3.000000     1020.500000
# 75%    1157.000000         14.000000     4.000000     1555.750000
# max    1499.000000         29.000000     5.000000     2068.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    48.000000        2.000000     1.000000
# 50%                   3.000000    66.000000        3.000000     2.000000
# 75%                   4.000000    83.750000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome  ...  StockOptionLevel  \
# count      1470.000000    1470.000000  ...       1470.000000
# mean          2.728571    6502.931293  ...          0.793878
# std           1.102846    4707.956783  ...          0.852077
# min           1.000000    1009.000000  ...          0.000000
# 25%           2.000000    2911.000000  ...          0.000000
# 50%           3.000000    4919.000000  ...          1.000000
# 75%           4.000000    8379.000000  ...          1.000000
# max           4.000000   19999.000000  ...          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1470.000000            1470.000000      1470.000000
# mean           11.279592               2.799320         2.761224
# std             7.780782               1.289271         0.706476
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%            10.000000               3.000000         3.000000
# 75%            15.000000               3.000000         3.000000
# max            40.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1470.000000         1470.000000              1470.000000
# mean         7.008163            4.229252                 2.187755
# std          6.126525            3.623137                 3.222430
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 3.000000
# max         40.000000           18.000000                15.000000
#
#        YearsWithCurrManager          Age    Attrition
# count           1470.000000  1470.000000  1470.000000
# mean               4.123129    36.923810     0.161224
# std                3.568136     9.135373     0.367863
# min                0.000000    18.000000     0.000000
# 25%                2.000000    30.000000     0.000000
# 50%                3.000000    36.000000     0.000000
# 75%                7.000000    43.000000     0.000000
# max               17.000000    60.000000     1.000000
#
# [8 rows x 25 columns]

# %%
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1470 total observations, 1233 right-censored observations>
#              duration col = 'Age'
#                 event col = 'Attrition'
#       baseline estimation = breslow
#    number of observations = 1470
# number of events observed = 237
#    partial log-likelihood = -1386.61
#          time fit was run = 2023-12-17 15:42:55 UTC
#
# ---
#                            coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# DailyRate                 -0.00       1.00       0.00            -0.00            -0.00                 1.00                 1.00
# DistanceFromHome           0.03       1.03       0.01             0.01             0.04                 1.01                 1.04
# Education                 -0.14       0.87       0.07            -0.28            -0.01                 0.76                 0.99
# EmployeeNumber            -0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# EnvironmentSatisfaction   -0.21       0.81       0.06            -0.33            -0.10                 0.72                 0.91
# HourlyRate                -0.00       1.00       0.00            -0.01             0.00                 0.99                 1.00
# JobInvolvement            -0.41       0.67       0.09            -0.58            -0.23                 0.56                 0.80
# JobLevel                  -0.03       0.97       0.22            -0.45             0.40                 0.63                 1.49
# JobSatisfaction           -0.28       0.76       0.06            -0.40            -0.16                 0.67                 0.85
# MonthlyIncome             -0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# MonthlyRate               -0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# NumCompaniesWorked         0.04       1.04       0.03            -0.02             0.09                 0.98                 1.10
# PercentSalaryHike         -0.06       0.94       0.03            -0.12             0.00                 0.89                 1.00
# PerformanceRating          0.37       1.45       0.30            -0.21             0.95                 0.81                 2.58
# RelationshipSatisfaction  -0.20       0.82       0.06            -0.32            -0.08                 0.73                 0.92
# StockOptionLevel          -0.48       0.62       0.09            -0.67            -0.30                 0.51                 0.74
# TotalWorkingYears         -0.16       0.85       0.02            -0.21            -0.12                 0.81                 0.89
# TrainingTimesLastYear     -0.12       0.89       0.05            -0.22            -0.02                 0.80                 0.98
# WorkLifeBalance           -0.18       0.84       0.09            -0.36            -0.00                 0.70                 1.00
# YearsAtCompany             0.09       1.09       0.03             0.03             0.15                 1.03                 1.16
# YearsInCurrentRole        -0.09       0.92       0.04            -0.16            -0.02                 0.85                 0.98
# YearsSinceLastPromotion    0.09       1.09       0.03             0.02             0.15                 1.03                 1.16
# YearsWithCurrManager      -0.09       0.92       0.04            -0.16            -0.02                 0.86                 0.98
#
#                            cmp to     z      p   -log2(p)
# covariate
# DailyRate                    0.00 -1.98   0.05       4.38
# DistanceFromHome             0.00  3.46 <0.005      10.86
# Education                    0.00 -2.15   0.03       4.99
# EmployeeNumber               0.00 -0.64   0.52       0.93
# EnvironmentSatisfaction      0.00 -3.55 <0.005      11.32
# HourlyRate                   0.00 -1.40   0.16       2.63
# JobInvolvement               0.00 -4.48 <0.005      17.02
# JobLevel                     0.00 -0.14   0.89       0.17
# JobSatisfaction              0.00 -4.54 <0.005      17.47
# MonthlyIncome                0.00 -0.46   0.64       0.64
# MonthlyRate                  0.00 -0.11   0.92       0.13
# NumCompaniesWorked           0.00  1.41   0.16       2.65
# PercentSalaryHike            0.00 -1.87   0.06       4.01
# PerformanceRating            0.00  1.24   0.21       2.23
# RelationshipSatisfaction     0.00 -3.37 <0.005      10.38
# StockOptionLevel             0.00 -5.11 <0.005      21.54
# TotalWorkingYears            0.00 -7.13 <0.005      39.82
# TrainingTimesLastYear        0.00 -2.25   0.02       5.37
# WorkLifeBalance              0.00 -1.98   0.05       4.41
# YearsAtCompany               0.00  2.75   0.01       7.40
# YearsInCurrentRole           0.00 -2.50   0.01       6.34
# YearsSinceLastPromotion      0.00  2.73   0.01       7.31
# YearsWithCurrManager         0.00 -2.41   0.02       5.96
# ---
# Concordance = 0.85
# Partial AIC = 2819.22
# log-likelihood ratio test = 344.44 on 23 df
# -log2(p) of ll-ratio test = 193.88

# %%
cph.plot()
# Out:
# <AxesSubplot:xlabel='log(HR) (95% CI)'>

# %% [markdown]
# ## 5. Analizar el efecto de una variable en el modelo de regresión de Cox

# %%
cph.plot_partial_effects_on_outcome(covariates='Age', values=[0, 2, 4, 6, 8, 10], cmap='coolwarm',figsize=(20,8))
plt.show()

# %% [markdown]
# ## 6. Seleccionar una muestra aleatoria y predecir su curva de supervivencia usando el modelo de Regresión de Cox

# %%
plt.figure(figsize=(20,4))
surv_func = cph.predict_survival_function(data_sample)
exp_lifetime = cph.predict_expectation(data_sample)
plt.plot(surv_func)
plt.legend(surv_func.columns)
plt.show()
