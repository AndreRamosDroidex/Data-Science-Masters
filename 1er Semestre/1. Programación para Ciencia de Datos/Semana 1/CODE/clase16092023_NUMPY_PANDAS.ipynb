# %%
#LIBRERIAS
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data\housesBrazil.csv')
df.shape
df.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture   hoa  rent amount property tax  fire insurance  total
# 0      furnished     0         8000         1000             121   9121
# 1  not furnished   540          820          122              11   1493
# 2      furnished  4172         7000         1417              89  12680
# 3  not furnished   700         1250          150              16   2116
# 4  not furnished     0         1200           41              16   1257

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'city', 'area', 'rooms', 'bathroom', 'parking spaces',
#        'floor', 'animal', 'furniture', 'hoa', 'rent amount', 'property tax',
#        'fire insurance', 'total'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0         city          area        rooms     bathroom  \
# count  6080.00000  6080.000000   6080.000000  6080.000000  6080.000000
# mean   3039.50000     0.863322    151.143914     2.492599     2.341612
# std    1755.28915     0.343535    375.559485     1.129665     1.438860
# min       0.00000     0.000000     10.000000     1.000000     1.000000
# 25%    1519.75000     1.000000     58.000000     2.000000     1.000000
# 50%    3039.50000     1.000000    100.000000     3.000000     2.000000
# 75%    4559.25000     1.000000    200.000000     3.000000     3.000000
# max    6079.00000     1.000000  24606.000000    10.000000    10.000000
#
#        parking spaces   rent amount  fire insurance          total
# count     6080.000000   6080.000000     6080.000000    6080.000000
# mean         1.756250   4395.844408       58.204276    6033.194572
# std          1.611909   3576.668946       49.313441    8751.347700
# ...

# %%
#Cambiar Columnas
df_cabecera = ['Rango', 'ciudad', 'areas', 'cuartos', 'baño', 'area de parqueo', 'Piso', 'animales', 'muebles', 'hoas'
                ,'monto de renta', 'Taxes','seguro', 'Total'] 
df.columns = df_cabecera
df.head()
# Out:
#    Rango  ciudad  areas  cuartos  baño  area de parqueo Piso   animales  \
# 0      0       1    240        3     3                4    -      acept
# 1      1       0     64        2     1                1   10      acept
# 2      2       1    443        5     5                4    3      acept
# 3      3       1     73        2     2                1   12      acept
# 4      4       1     19        1     1                0    -  not acept
#
#          muebles  hoas  monto de renta Taxes  seguro  Total
# 0      furnished     0            8000  1000     121   9121
# 1  not furnished   540             820   122      11   1493
# 2      furnished  4172            7000  1417      89  12680
# 3  not furnished   700            1250   150      16   2116
# 4  not furnished     0            1200    41      16   1257

# %%
#Guardar Archivo en Carpeta
ruta_salida = 'Data' + '/' + 'nuevoHousesBrazil.csv'
df.to_csv(ruta_salida)

# %%
##Tipos de datos
df.dtypes
# Out:
# Rango               int64
# ciudad              int64
# areas               int64
# cuartos             int64
# baño                int64
# area de parqueo     int64
# Piso               object
# animales           object
# muebles            object
# hoas               object
# monto de renta      int64
# Taxes              object
# seguro              int64
# Total               int64
# dtype: object

# %%
#Estadistica mas profunda
df.describe(include="all")
# Out:
#              Rango       ciudad         areas      cuartos         baño  \
# count   6080.00000  6080.000000   6080.000000  6080.000000  6080.000000
# unique         NaN          NaN           NaN          NaN          NaN
# top            NaN          NaN           NaN          NaN          NaN
# freq           NaN          NaN           NaN          NaN          NaN
# mean    3039.50000     0.863322    151.143914     2.492599     2.341612
# std     1755.28915     0.343535    375.559485     1.129665     1.438860
# min        0.00000     0.000000     10.000000     1.000000     1.000000
# 25%     1519.75000     1.000000     58.000000     2.000000     1.000000
# 50%     3039.50000     1.000000    100.000000     3.000000     2.000000
# 75%     4559.25000     1.000000    200.000000     3.000000     3.000000
# max     6079.00000     1.000000  24606.000000    10.000000    10.000000
#
#         area de parqueo  Piso animales        muebles  hoas  monto de renta  \
# ...

# %%
#Vizualizar columnas espeficcas
df['seguro'].head()

df['seguro'].describe()
# Out:
# count    6080.000000
# mean       58.204276
# std        49.313441
# min         3.000000
# 25%        23.000000
# 50%        41.000000
# 75%        77.000000
# max       677.000000
# Name: seguro, dtype: float64

# %%
#Segemento fila en especial
df.iloc[0, 3:-1]
# Out:
# cuartos                    3
# baño                       3
# area de parqueo            4
# Piso                       -
# animales               acept
# muebles            furnished
# hoas                       0
# monto de renta          8000
# Taxes                   1000
# seguro                   121
# Name: 0, dtype: object

# %%
#Segemento fila en especial
df.iloc[:, 3:-1]
# Out:
#       cuartos  baño  area de parqueo Piso   animales        muebles  hoas  \
# 0           3     3                4    -      acept      furnished     0
# 1           2     1                1   10      acept  not furnished   540
# 2           5     5                4    3      acept      furnished  4172
# 3           2     2                1   12      acept  not furnished   700
# 4           1     1                0    -  not acept  not furnished     0
# ...       ...   ...              ...  ...        ...            ...   ...
# 6075        2     1                1    2      acept  not furnished   420
# 6076        2     2                1   16  not acept      furnished   768
# 6077        1     1                0   13      acept  not furnished   250
# 6078        3     2                2    -  not acept  not furnished     0
# 6079        2     1                1    4      acept      furnished   489
#
#       monto de renta Taxes  seguro
# 0               8000  1000     121
# ...

# %%
#Segemento fila en especial

mask = (df['baño']>3) & (df['baño']>3)
df[mask]
# Out:
#       Rango  ciudad  areas  cuartos  baño  area de parqueo Piso   animales  \
# 2         2       1    443        5     5                4    3      acept
# 13       13       1    375        4     5                5    1      acept
# 24       24       1    180        3     5                3    3      acept
# 27       27       1    300        3     4                2    9      acept
# 32       32       1    250        3     4                2    -      acept
# ...     ...     ...    ...      ...   ...              ...  ...        ...
# 6063   6063       1    210        4     4                3   13  not acept
# 6067   6067       1    280        4     4                3   17      acept
# 6070   6070       1    200        4     5                3    2      acept
# 6071   6071       0    600        5     5                4    -      acept
# 6072   6072       1    200        4     4                4   21      acept
#
#             muebles  hoas  monto de renta Taxes  seguro  Total
# ...

# %%
##df.max()
df.mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_13864/1830741388.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Rango              3039.500000
# ciudad                0.863322
# areas               151.143914
# cuartos               2.492599
# baño                  2.341612
# area de parqueo       1.756250
# monto de renta     4395.844408
# seguro               58.204276
# Total              6033.194572
# dtype: float64

# %%
#Datos faltantes
df.dropna()
